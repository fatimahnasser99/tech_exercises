# %% [markdown]
# **Question:**
#
# **Example:**
#
# - Input:
# - Output:
#
# **Template:**
#
# ```python
#
# ```

# %% [markdown]
# <b>Solution Methodology:</b><br>
#
# <b>steps:</b>
#
# 1. step header:<br>description/reason
#
# 2.

# %%
# solution

# %%
#testing

# %% [markdown]
# <b>Possible enhancement</b>
